# %% [markdown]
# <a href="https://colab.research.google.com/github/jinny520/22JG/blob/main/8_%EC%98%88%EC%8B%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EB%B3%B4%EA%B3%A0%EC%84%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 분석 보고서 작성하기

# %% [markdown]
# 1. 데이터 조사하기
# 2. 질문하기
# 3. 문제정의
# 4. 알고리즘 설계
# 5. 코드 구현

# %% [markdown]
# 책 "모두의 데이터 분석" ebook 링크 공유합니다.
# 다양한 데이터 분석 사례가 나와있으니 참고하여도 좋습니다.
#
#
# *  책의 사례 그대로 보고서에 사용X (감점됨)
# *  https://thebook.io/007029/

# %% [markdown]
# ## 1. 데이터 조사하기

# %% [markdown]
# 1) 관심있는 데이터를 찾는 것부터 시작한다.<br>
# 2) 공공데이터포털( http://www.data.go.kr )<br>
# 3) 기후 변화 관련 데이터<br>
#    ( https://data.kma.go.kr/data/gaw/selectGHGsRltmList.do?pgmNo=587 )  <br>
# 4) 기상청 기후정보포털 (http://www.climate.go.kr/home/) <br>
# 5) 관심 있는 분야 인터넷 검색 후 데이터 수집<br>

# %%
# 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumGothic') 
mpl.font_manager._rebuild()
#[런타임] - [런타임 재시작] 후
#코드 재실행
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.

# %%
# 데이터 가져오기 코드1 (데이터 읽어오기 코드 1,2중 선택하여 사용)
# shift+enter로 실행하여 데이터 파일을 선택하세요.
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5b2f7f31-3a29-4f1e-b11d-31d3d9f317a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b2f7f31-3a29-4f1e-b11d-31d3d9f317a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving age.csv to age (1).csv

# %%
#데이터 가져오기 코드2 (데이터 읽어오기 코드 1,2중 선택하여 사용)
# !git clone https://github.com/jinny520/22JG/
# Out:
# fatal: destination path '22JG' already exists and is not an empty directory.

# %%
ls
# Out:
# 22JG/  sample_data/

# %%
cd 22JG
# Out:
# /content/22JG

# %%
ls
# Out:
#  1_ans_print_input_varient_.ipynb
#  1_exercise_input_output_varient.ipynb
#  제출과제_20101_김진건.ipynb
#  2_조건문_21000_김진건.ipynb
#  2_ans_조건문_30800_김진건.ipynb
#  3_리스트_21000_김진건.ipynb
#  4_반복문_20101_김진건.ipynb
#  4.ans_반복문.ipynb
# '5_데이터시각화(21000김진건).ipynb'
#  6_데이터분석기초_21000김진건.ipynb
# '8_데이터분석보고서_양식(21010김진건).ipynb'
#  age.csv
#  card.csv
#  imaage/
#  TrafficCard.xls

# %% [markdown]
# ## 2. 데이터 속성 (수행 문제해결과정평가:라이브러리 이용 프로그램 작성)
# *   핵심 속성을 찾기 위해
# *   속성별 연관성을 발견할 수 있도록 그래프로 시각화하기

# %%
#파일 읽기 코드1 (파일 읽기 코드 1,2 중 선택하여 사용)
import csv 
 
f = open('age.csv',encoding="CP949")         # 파일 오픈
data = csv.reader(f)         # 파일 읽기 reader
next(data)                   # 파일 헤더 건너뛰기 
next(data)                   # 파일 헤더 건너뛰기 
data = list(data)            # 파일 리스트로 바꾸기

#리스트에 데이터 저장 
region= []
people=[]
for row in data:
    region.append(row[0])
    people.append(int(row[1]))
print(region)
print(people) 

# 그래프 그리기
import matplotlib.pyplot as plt
plt.barh(region,people)
plt.xlabel('인구수')
plt.ylabel('지역')
plt.title("남양주 지역별 인구수")
plt.show()
# Out:
# ['와부읍', ' 진접읍', '화도읍', '화도읍동부출장소', '화도읍남부출장소', '진건읍', '오남읍', '퇴계원읍', '별내면', '수동면', '조안면', '호평동', '평내동', '금곡동', '양정동', '다산1동', '다산2동', '별내동']
# [59343, 96163, 66473, 14677, 36992, 23084, 52927, 28612, 19306, 8945, 4080, 57310, 36352, 18322, 4011, 93271, 35523, 79251]

# %%
#파일 읽어오기 코드2 (파일 읽기 코드 1,2 중 선택하여 사용)
import pandas as pd
df = pd.read_csv('seoultemp(year,2021).csv')
df = df.fillna(method='bfill')

# 연도, 평균기온 데이터 저장하기
year = df['년'].values
temp = df['평균기온(℃)'].values

# 산점도(scatter) 그리기
import matplotlib.pyplot as plt
plt.scatter(year,temp)
plt.xlabel('year')
plt.ylabel('temp')
plt.title("연도 별 평균기온")
plt.show()

# %% [markdown]
# ### * 핵심속성은?
# #### <font color='blue' font size=5> 청소년 인구수(13-19세)</font>
# ### * 속성의 의미와 관계 설명하기
# #### <font color='blue' font size=5> 지역별 청소년 인구를 분석하면 어느 지역에 학생들과 젊은 부부들이 많이 거주하는지 알 수 있다. 인구절벽 현상을 짐작할 수 있는 핵심 속성이다.</font>

# %% [markdown]
# ## 3. 질문하기

# %% [markdown]
# ### 3-1. 질문하기(3가지 이상 작성)

# %% [markdown]
# *   관심과 흥미가 있는 데이터를 보면서 데이터가 어떤 내용을 담고 있는지, 또 어떤 내용은 담고 있지 않은지
# *   데이터가 기록된 기간은 언제부터 언제까지인지
# *   어떤 형태로 시각화해보면 어떤 정보를 알수 있는지
#
#
# 등의 질문을 생각하면서 그 중 재미있는 질문들을 찾아내어 적어보도록 하자

# %% [markdown]
# 1) 전국에서 영유아들이 가장 많이 사는 지역은 어디일까?<br>
# 2) 보통 학군이 좋다고 알려진 지역에는 청소년들이 많이 살까?<br>
# 3) 광역시 데이터를 10년 단위로 살펴보면 청년 비율이 줄고 있다는 사실을 알 수 있을까?<br>
# 4) 경기도에서 지난 5년간 인구가 가장 많이 증가한 구는 어디일까?<br>
# 5) 우리 동네의 인구 구조와 가장 비슷한 동네는 어디일까?<br>
# * 데이터에 질문을 잘 찾아내어 가치 있는 정보를 만들어 가는 과정이 데이터분석 프로젝트 활동의 목적임

# %% [markdown]
# ### 2-2. 데이터 관련 내용 조사

# %% [markdown]
# 1) 인구 절벽이란? <br>
# 인구절벽(人口絶壁)은 미국의 경제학자 해리 덴트(Harry Dent)가 주장했던 이론이다. 어느 순간을 기점으로 한 국가나 구성원의 인구가 급격히 줄어들어 인구 분포가 마치 절벽이 깎인 것처럼 역삼각형 분포가 된다는 내용이다. 주로 생산가능인구(만 15~64세)가 급격히 줄어들고 고령인구(만 65세이상)가 급속도로 늘어나는 경우를 말한다.

# %% [markdown]
# 2) 인구 절벽의 전망<br>
# 인구절벽은 사실이라기 보다는 어디까지나 앞으로의 사회현상을 예측하기 위한 이론이기 때문에 현실과 동일시해서는 안된다.
#
# 이러한 인구 절벽론에 대해서 현재 학계는 비관론과 낙관론이 대립하는 양상을 띠고 있다. 인구절벽 이론이 정말 실현될지는 때가 되지 않고서는 아무도 알 수 없고, 인구절벽 이론이 장기적으로 저출산과 고령화사회를 경험하고 있는 몇몇 국가의 사례에 들어맞지 않는 경우[2]도 있으며, 철저하게 정부와 기업의 입장에서 설명되기에 특정 계층을 위한 이론이라는 비판도 있다.
#
# 비관론에서 말하듯 인구절벽이라는게 정말로 일어날 위기의 상황이든, 낙관론에서 말하듯 일어나지 않을 현상인지는 둘째치더라도, 현재 저출산 추세로 인구가 감소하는 것은 기정 사실이기에 이에 대한 대비[3]가 필요하다는 점에는 대부분이 공감한다.

# %% [markdown]
# 3) 인구 절벽의 비관론<br>
#  - 관련 내용 조사

# %% [markdown]
# 4) 인구 절벽의 낙관론<br>
# - 관련 내용 조사

# %% [markdown]
# 5) 환경 문제 관련<br>
# - 지구온난화를 줄이는 방법은 인구 절벽을 받아들이는 것 뿐이라는 주장도 나오고 있다.

# %% [markdown]
# ## 3. 문제정의

# %% [markdown]
# * 질문을 명확한 문제로 정의하기<br>
# 1) 전국에서 영유아들이 가장 많이 사는 지역은 어디일까?<br>
# => '전국에 있는 읍면동 중 만 0세 이상 6 세 이하의 인구 비율이 높은 상위 10 곳은 어디일까?' 라는 질문으로 변경<br>
# 2) 보통 학군이 좋다고 알려진 지역에는 청소년들이 많이 살까?<br>
# => 보통 학군이 좋다고 알려진 지역에는 만 13세 이상 만 19세 미만의 청소년들이 많이 살까?<br>
# 3) 광역시 데이터를 10년 단위로 살펴보면 청년 비율이 줄고 있다는 사실을 알 수 있을까?<br>
# => 광역시 데이터를 10년 단위로 살펴보면 만 19세 이상 청년 비율이 줄고 있다는 사실을 알 수 있을까? <br>
# 4) 우리 동네의 인구 구조와 가장 비슷한 동네는 어디일까?<br>
# => 남양주 내에 진건읍의 인구 구조와 가장 비슷한 인구 구조를 가진 동네는 어디일까?
#
# * 데이터분석 프로젝트 주제로 최종 1개 선택

# %% [markdown]
# ### * 최종 질문 작성하기
# <font color='blue' font size=5>남양주시에서 진건읍의 연령별 인구 구조와 가장 형태가 비슷한 지역은 어디일까?</font>

# %% [markdown]
# ## 4. 알고리즘 설계

# %% [markdown]
# * 문제 해결을 위한 5단계<br>
# 1) 데이터를 읽어온다.<br>
# 2) 궁금한 지역의 이름을 입력받는다.<br>
# 3) 궁금한 지역의 인구 구조를 저장한다.<br>
# 4) 궁금한 지역의 인구 구조와 가장 비슷한 인구 구조를 가진 지역을 찾는다.<br>
# 5) 가장 비슷한 곳의 인구 구조와 궁금한 지역의 인구 구조를 시각화한다.

# %% [markdown]
# ## 5. 코드작성

# %% [markdown]
# * The book 교재 Unit14 Numpy를 활용한 나만의 프로젝트 만들기에서 알고리즘 설계 부분 참고

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import numpy as np
import csv

#1. 데이터를 읽어온다.
f =open('age.csv', encoding='cp949')
data = csv.reader(f, delimiter=',')
next(data)
data = list(data)

#2. 궁금한 지역의 이름을 입력받는다.
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
mn =1
result_name =''
result =0

#3. 궁금한 지역의 인구 구조를 저장한다.
for row in data :
    if name in row[0] :
        home = np.array(row[3:], dtype =int) / int(row[2])

#4. 궁금한 지역의 인구 구조와 가장 비슷한 인구 구조를 가진 지역을 찾는다.
for row in data :
    away = np.array(row[3:], dtype =int) / int(row[2])
    s = np.sum((home - away) **2)
    if s < mn and name not in row[0] :
        mn = s
        result_name = row[0]
        result = away
        
#5. 궁금한 지역의 인구 구조와 가장 비슷한 곳의 인구 구조를 시각화한다.
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize = (6,3), dpi=300)            
plt.rc('font', family ='NanumBarunGothic')
plt.title(name +' 지역과 가장 비슷한 인구 구조를 가진 지역')
plt.plot(home, label = name)
plt.plot(result, label = result_name)
plt.legend()
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 진건

# %% [markdown]
# ## 6. 소감문 작성
# 교과서 88쪽 ~ 143쪽 참고하여 아래 1~3번 질문에 답변해보아요 :)

# %% [markdown]
# 1) 기계학습의 개념<br>
# *   기계학습의 개념에 대해 서술
# *   자신의 프로젝트에 사용한 기계학습 알고리즘에 대해 설명(기계학습을 적용한 경우에만 서술)

# %% [markdown]
# 2) 정형 데이터와 비정형 데이터<br>
# *   정형 데이터와 비정형 데이터의 개념에 대해 서술
# *   자신의 프로젝트에 사용된 자료는 정형데이터와 비정형 데이터 중 어떤 것인가요? 왜 그렇게 생각했나요?

# %% [markdown]
# 3) 데이터와 기계학습과의 연관성에 대해 설명하세요<br>

# %% [markdown]
# 4) 데이터 분석 활동을 하며 느낀점에 대해 서술

# %% [markdown]
# ### * 제출안내
# ## 이 파일을 .ipynb형식으로 다운로드 받아 리로에 제출
